# %%
import sys
import os

current_dir = os.getcwd()

jepa_dir = os.path.abspath('/storage/home/basileterv/jepa-internal')

print(f"{jepa_dir=}")

sys.path.append(jepa_dir)
local_vjepa_wm_dir = os.path.join(jepa_dir, "app/vjepa_wm/local")
print(f"{local_vjepa_wm_dir=}")

# from app.vjepa_wm.local.logs_plan_joint_utils
from app.vjepa_wm.local.logs_plan_joint_unif_utils import (collect_task_eval_data, plot_task_eval_data,
    eval_setup_aliases, eval_setup_aliases_full_plan_step,
    # eval_setup_aliases_new_ng_only,
)
# Out:
# jepa_dir='/storage/home/basileterv/jepa-internal'
# local_vjepa_wm_dir='/storage/home/basileterv/jepa-internal/app/vjepa_wm/local'

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'action_ratio_exps')
base_dir = os.path.join(base_dir, 'pt')
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/pt_sweep/pt_4f_fsk5_ask1_r128_pred_vj2ac_dv3vitl_depth6_noprop_repro_1roll_save',
     'seqcond'),
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/pt_sweep/pt_4f_fsk5_ask1_r128_pred_vj2acftcond_dv3vitl_depth6_noprop_repro_1roll_save',
     'ftcond'),
]

task_subset = ["pt"]

task_eval_data = collect_task_eval_data(
  model_training_folders,
  task_subset,
  eval_setup_aliases=eval_setup_aliases,
)

plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  truncate_epoch=50, y_min=0, y_max=55,
  average_seeds=True,
)
# Out:
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/pt/pt_NG $L_2$_success rate (%)_evolution.pdf
# Plotting pt/NG $L_2$/Success Rate (%) took 0.38 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/pt/pt_NG $L_1$_success rate (%)_evolution.pdf
# Plotting pt/NG $L_1$/Success Rate (%) took 0.37 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/pt/pt_CEM $L_2$_success rate (%)_evolution.pdf
# Plotting pt/CEM $L_2$/Success Rate (%) took 0.36 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/pt/pt_CEM $L_1$_success rate (%)_evolution.pdf
# Plotting pt/CEM $L_1$/Success Rate (%) took 0.38 seconds
# Plotting all tasks took 1.49 seconds

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'action_ratio_exps')
base_dir = os.path.join(base_dir, 'wall')
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/wall_sweep/wall_4f_fsk5_ask1_r128_pred_vj2ac_dv3vitl_depth6_noprop_repro_1roll_save_2n',
     'seqcond'),
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/wall_sweep/wall_4f_fsk5_ask1_r128_pred_vj2acftcond_dv3vitl_depth6_noprop_repro_1roll_save_2n',
     'ftcond'),
]

task_subset = ["wall"]

task_eval_data = collect_task_eval_data(
  model_training_folders,
  task_subset,
  eval_setup_aliases=eval_setup_aliases,
)

plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  truncate_epoch=50, y_min=0, y_max=75,
  average_seeds=True,
)
# Out:
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/wall/wall_CEM rand $L_2$_success rate (%)_evolution.pdf
# Plotting wall/CEM rand $L_2$/Success Rate (%) took 0.39 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/wall/wall_NG rand $L_2$_success rate (%)_evolution.pdf
# Plotting wall/NG rand $L_2$/Success Rate (%) took 0.39 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/wall/wall_CEM rand $L_1$_success rate (%)_evolution.pdf
# Plotting wall/CEM rand $L_1$/Success Rate (%) took 0.54 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/wall/wall_NG rand $L_1$_success rate (%)_evolution.pdf
# Plotting wall/NG rand $L_1$/Success Rate (%) took 0.40 seconds
# Plotting all tasks took 1.72 seconds

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'action_ratio_exps')
base_dir = os.path.join(base_dir, 'droid')
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_final_sweep/droid_4f_fps4_r128_pred_vj2ac_dv3vitl_depth6_noprop_repro_1roll_4fpcs_save_2n',
     'seqcond'),
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_final_sweep/droid_4f_fps4_r128_pred_vj2acftcond_dv3vitl_depth6_noprop_repro_1roll_4fpcs_save_2n',
     'ftcond'),
]

task_subset = ["droid", "droid-base"]

task_eval_data = collect_task_eval_data(
  model_training_folders,
  task_subset,
  eval_setup_aliases=eval_setup_aliases,
  collect_subfolder_seeds=False,
  verbose=True,
)

plot_task_eval_data(
    task_eval_data=task_eval_data,
    y_values=["Act_err_xyz"],
    smooth=True,
    alpha=0.2,
    show_original=True,
    base_dir=base_dir,
    truncate_epoch=316,
    y_min=0.,
    y_max=1.,
    xtick_step=20,
    y_log_scale=3,
    x_log_scale=False,
    average_seeds=True,
    eval_setup_aliases=eval_setup_aliases,
)
# Out:
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/droid/droid_CEM H3 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_1$ max0.1/Action error XYZ took 0.44 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/droid/droid_NG H3 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/NG H3 $L_2$ max0.1/Action error XYZ took 0.42 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/droid/droid_NG H3 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/NG H3 $L_1$ max0.1/Action error XYZ took 0.48 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/droid/droid_CEM H3 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_2$ max0.1/Action error XYZ took 0.42 seconds
# Plotting all tasks took 1.75 seconds

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'action_ratio_exps')
base_dir = os.path.join(base_dir, 'mw')
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/mw_sweep/mw_4f_fsk5_ask1_r128_pred_vj2ac_dv3vitl_depth6_noprop_repro_1roll_save',
     'seqcond'),
    ('/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/mw_sweep/mw_4f_fsk5_ask1_r128_pred_vj2acftcond_dv3vitl_depth6_noprop_repro_1roll_save',
     'ftcond'),
]

task_subset = ["mw-reach", "mw-reach-wall", "reach", "reach-wall"]

task_eval_data = collect_task_eval_data(
  model_training_folders,
  task_subset,
  eval_setup_aliases=eval_setup_aliases,
  collect_subfolder_seeds=False,
  verbose=True,
)

plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  truncate_epoch=50, y_min=0, y_max=75,
  average_seeds=True,
)
# Out:
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/mw/mw-reach_CEM $L_1$_success rate (%)_evolution.pdf
# Plotting mw-reach/CEM $L_1$/Success Rate (%) took 0.49 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/mw/mw-reach-wall_CEM $L_2$_success rate (%)_evolution.pdf
# Plotting mw-reach-wall/CEM $L_2$/Success Rate (%) took 0.38 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/mw/mw-reach-wall_NG $L_2$_success rate (%)_evolution.pdf
# Plotting mw-reach-wall/NG $L_2$/Success Rate (%) took 0.39 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/action_ratio_exps/mw/mw-reach_NG $L_1$_success rate (%)_evolution.pdf
# Plotting mw-reach/NG $L_1$/Success Rate (%) took 0.39 seconds
# ...

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'droid_fractions_comp')
base_dir = os.path.join(base_dir, 'droid_sweep/')
print(f"{base_dir=}")
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.02_r256_predAdaLN0_vj2vitl_depth24_noprop_muon_1roll",
     "2%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.1_r256_predAdaLN0_vj2vitl_depth24_noprop_muon_1roll",
     "frac10%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.25_r256_predAdaLN0_vj2vitl_depth24_noprop_muon_1roll",
     "frac25%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.5_r256_predAdaLN0_vj2vitl_depth24_noprop_muon_1roll",
     "frac50%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.75_r256_predAdaLN0_vj2vitl_depth24_noprop_muon_1roll",
     "frac75%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0_vj2vitl_depth24_noprop_muon_1roll",
     "frac100%"),
]
task_subset = ["droid-base", "droid"]
exclude_eval_folders = [
    "droid_L2_cem_sourcedset_H6_nas6_ctxt2_gH6_r256_alpha0.0_ep32_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",

    "droid_L2_ng_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",
]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    # eval_setup_aliases=eval_setup_aliases_full_plan_step,
    exclude_eval_folders=exclude_eval_folders,
)

plot_task_eval_data(
    task_eval_data, y_values=['Act_err_xyz'], smooth=True, alpha=0.2,
    show_original=True, base_dir=base_dir, put_title=True,
    eval_setup_aliases=eval_setup_aliases,
    truncate_epoch=100, y_min=0., y_max=1., xtick_step=20,
    y_log_scale=3, x_log_scale=False
)
# Out:
# base_dir='/storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_sweep/'
# No data found in droid_L2_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH1_r256_alpha0.0_ep64_decode
# No data found in droid_L2_cem_sourcedset_H6_nas6_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep64_decode
# No data found in droid_L1_cem_sourcedset_H3_nas3_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep64_decode
# No data found in droid_L1_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH1_r256_alpha0.0_ep64_decode
# No data found in droid_L1_cem_sourcedset_H6_nas6_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep64_decode
# No data found in droid_L2_cem_sourcedset_H3_nas3_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep64_decode
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_sweep/droid_CEM H6 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H6 $L_2$ max0.1/Action error XYZ took 0.33 seconds
# ...

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'droid_fractions_comp')
base_dir = os.path.join(base_dir, 'droid_batchify_sweep/')
print(f"{base_dir=}")
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.02_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
     "2%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.1_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
     "frac10%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.25_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
     "frac25%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.5_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
     "frac50%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.75_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
     "frac75%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
     "frac100%"),
]
task_subset = ["droid-base", "droid"]
exclude_eval_folders = [
    "droid_L2_cem_sourcedset_H6_nas6_ctxt2_gH6_r256_alpha0.0_ep32_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",

    "droid_L2_ng_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",
]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    # eval_setup_aliases=eval_setup_aliases_full_plan_step,
    exclude_eval_folders=exclude_eval_folders,
)

plot_task_eval_data(
    task_eval_data, y_values=['Act_err_xyz'], smooth=True, alpha=0.2,
    show_original=True, base_dir=base_dir, put_title=True,
    eval_setup_aliases=eval_setup_aliases,
    truncate_epoch=100, y_min=0., y_max=1., xtick_step=20,
    y_log_scale=3, x_log_scale=False
)
# Out:
# base_dir='/storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_batchify_sweep/'
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_batchify_sweep/droid_CEM H1 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H1 $L_2$ max0.1/Action error XYZ took 0.43 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_batchify_sweep/droid_CEM H6 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H6 $L_2$ max0.1/Action error XYZ took 0.34 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_batchify_sweep/droid_CEM H1 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H1 $L_1$ max0.1/Action error XYZ took 0.35 seconds
# ...

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'droid_fractions_comp')
base_dir = os.path.join(base_dir, 'droid_causal_sweep/')
print(f"{base_dir=}")
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.02_r256_predAdaLN0_vj2vitlcaus_depth24_noprop_muon_1roll",
     "2%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.1_r256_predAdaLN0_vj2vitlcaus_depth24_noprop_muon_1roll",
     "frac10%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.25_r256_predAdaLN0_vj2vitlcaus_depth24_noprop_muon_1roll",
     "frac25%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.5_r256_predAdaLN0_vj2vitlcaus_depth24_noprop_muon_1roll",
     "frac50%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.75_r256_predAdaLN0_vj2vitlcaus_depth24_noprop_muon_1roll",
     "frac75%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0_vj2vitlcaus_depth24_noprop_muon_1roll",
     "frac100%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.02_r256_predAdaLN0_vj2vitlcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "2%-nodup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.1_r256_predAdaLN0_vj2vitlcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "frac10%-nodup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.25_r256_predAdaLN0_vj2vitlcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "frac25%-nodup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.5_r256_predAdaLN0_vj2vitlcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "frac50%-nodup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.75_r256_predAdaLN0_vj2vitlcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "frac75%-nodup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0_vj2vitlcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "frac100%-nodup"),
]
task_subset = ["droid-base", "droid"]
exclude_eval_folders = [
    "droid_L2_cem_sourcedset_H6_nas6_ctxt2_gH6_r256_alpha0.0_ep32_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",

    "droid_L2_ng_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",
]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    # eval_setup_aliases=eval_setup_aliases_full_plan_step,
    exclude_eval_folders=exclude_eval_folders,
)

plot_task_eval_data(
    task_eval_data, y_values=['Act_err_xyz'], smooth=True, alpha=0.2,
    show_original=True, base_dir=base_dir, put_title=True,
    eval_setup_aliases=eval_setup_aliases,
    truncate_epoch=100, y_min=0., y_max=1., xtick_step=20,
    y_log_scale=3, x_log_scale=False
)
# Out:
# base_dir='/storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_causal_sweep/'
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_causal_sweep/droid_CEM H1 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H1 $L_2$ max0.1/Action error XYZ took 0.50 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_causal_sweep/droid_CEM H3 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_2$ max0.1/Action error XYZ took 0.49 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/droid_causal_sweep/droid_CEM H6 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H6 $L_2$ max0.1/Action error XYZ took 0.64 seconds
# ...

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'droid_fractions_comp')
base_dir = os.path.join(base_dir, 'vj2_hier_droid_sweep/')
print(f"{base_dir=}")
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.02_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
    #  "2%"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.1_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
    #  "frac10%"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.25_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
    #  "frac25%"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.5_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
    #  "frac50%"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac0.75_r256_predAdaLN0_vj2vitl_batchif_depth24_noprop_muon_1roll",
    #  "frac75%"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitgcaus_nodup_actsk2_depth24_noprop_muon_1roll",
     "frac100%-nodup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitgcaus_depth24_noprop_muon_1roll",
     "frac100%-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitg_batchif_depth24_noprop_muon_1roll",
     "frac100%-batch-dup"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitg_batchif_nodup_depth24_noprop_muon_1roll",
     "frac100%-batch-nodup"),
]
task_subset = ["droid-base", "droid"]
exclude_eval_folders = [
    "droid_L2_cem_sourcedset_H6_nas6_ctxt2_gH6_r256_alpha0.0_ep32_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",

    "droid_L2_ng_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",
]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    # eval_setup_aliases=eval_setup_aliases_full_plan_step,
    exclude_eval_folders=exclude_eval_folders,
)

plot_task_eval_data(
    task_eval_data, y_values=['Act_err_xyz'], smooth=True, alpha=0.2,
    show_original=True, base_dir=base_dir, put_title=True,
    eval_setup_aliases=eval_setup_aliases,
    truncate_epoch=100, y_min=0., y_max=1., xtick_step=20,
    y_log_scale=3, x_log_scale=False
)
# Out:
# base_dir='/storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/vj2_hier_droid_sweep/'
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/vj2_hier_droid_sweep/droid_CEM H3 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_2$ max0.1/Action error XYZ took 0.31 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/vj2_hier_droid_sweep/droid_CEM H6 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H6 $L_1$ max0.1/Action error XYZ took 0.31 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/vj2_hier_droid_sweep/droid_CEM H3 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_1$ max0.1/Action error XYZ took 0.43 seconds
# ...

# %%
base_dir = os.path.join(local_vjepa_wm_dir, 'droid_fractions_comp')
base_dir = os.path.join(base_dir, 'VJ2.5_comp/')
print(f"{base_dir=}")
os.makedirs(base_dir, exist_ok=True)
model_training_folders = [
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitg_predvj2ac_L1_2roll_save_4n_wsd_seed1",
     "vj2-5vitg-AC"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitg_predvj2ac_L1_2roll_noprop_save_4n_wsd_seed1",
     "vj2-5vitg-AC-noprop"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitg_predvj2ac_L1_2roll_noprop_save_4n_wsd_clip1_beta0995_seed1",
     "vj2-5vitg-AC-noprop-clip-beta"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitl256_predvj2ac_L1_2roll_save_4n_wsd_seed1",
     "vj2-5vitl-AC"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitl256_predvj2ac_L1_2roll_save_4n_wsd_clip1_beta0995_seed1",
     "vj2-5vitl-AC-clip-beta"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitl256_predvj2ac_L1_2roll_noprop_save_4n_wsd_seed1",
     "vj2-5vitl-AC-noprop"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitldist384_predvj2ac_L1_2roll_save_4n_wsd_seed1",
     "vj2-5vitl384-AC"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitldist384_predvj2ac_L1_2roll_save_4n_wsd_clip1_beta0995_seed1",
     "vj2-5vitl384-AC-clip-beta"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_r256_vj2-5vitldist384_predvj2ac_L1_2roll_noprop_save_4n_wsd_seed1",
     "vj2-5vitl384-AC-noprop"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_final_sweep/droid_8fpcs_fps4_r256_vj2acvitgL1_repro_2roll_noprop_save_4n_wsd_seed1",
     "VJ2AC-noprop"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_final_sweep/droid_8fpcs_fps4_r256_vj2acvitgL1_repro_2roll_save_4n_wsd_seed1",
     "VJ2AC"),
    ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_final_sweep/droid_8fpcs_fps4_r256_vj2acvitgL1_repro_2roll_noprop_save_4n_wsd_clip1_beta0995_seed1",
     "VJ2AC-noprop-clip-beta"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitgcaus_nodup_actsk2_depth24_noprop_muon_1roll",
    #  "frac100%-nodup"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitgcaus_depth24_noprop_muon_1roll",
    #  "frac100%-dup"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitg_batchif_depth24_noprop_muon_1roll",
    #  "frac100%-batch-dup"),
    # ("/checkpoint/amaia/video/basileterv/experiment/vjepav2/vjepa_wm/droid_fractions/droid_8fpcs_fps4_lrcams_frac1_r256_predAdaLN0vitl_vj2-5vitg_batchif_nodup_depth24_noprop_muon_1roll",
    #  "frac100%-batch-nodup"),
]
task_subset = ["droid-base", "droid"]
exclude_eval_folders = [
    "droid_L2_cem_sourcedset_H6_nas6_ctxt2_gH6_r256_alpha0.0_ep32_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_cem_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",

    "droid_L2_ng_sourcedset_H1_nas1_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H1_nas1_maxnorm01_momentum015_ctxt2_gH3_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_ctxt2_gH6_r256_alpha0.0_ep16_decode",
    "droid_L2_ng_sourcedset_H3_nas3_maxnorm01_momentum015_ctxt2_gH6_r256_alpha0.0_ep16_decode",
]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    # eval_setup_aliases=eval_setup_aliases_full_plan_step,
    exclude_eval_folders=exclude_eval_folders,
)

plot_task_eval_data(
    task_eval_data, y_values=['Act_err_xyz'], smooth=True, alpha=0.2,
    show_original=True, base_dir=base_dir, put_title=True,
    eval_setup_aliases=eval_setup_aliases,
    truncate_epoch=315, y_min=0., y_max=1., xtick_step=20,
    y_log_scale=3, x_log_scale=False
)
# Out:
# base_dir='/storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/VJ2.5_comp/'
# No data found in droid_L1_ng_sourcedset_H3_nas3_maxnorm01_ctxt2_gH3_r256_alpha0.0_ep64_decode
# ...
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/VJ2.5_comp/droid_CEM H3 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_1$ max0.1/Action error XYZ took 0.65 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/VJ2.5_comp/droid_CEM H6 $L_1$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H6 $L_1$ max0.1/Action error XYZ took 0.65 seconds
# Saved plot to /storage/home/basileterv/jepa-internal/app/vjepa_wm/local/droid_fractions_comp/VJ2.5_comp/droid_CEM H3 $L_2$ max0.1_action error xyz_evolution.pdf
# Plotting droid/CEM H3 $L_2$ max0.1/Action error XYZ took 0.62 seconds
# ...
