# %%
import sys
import os

# Import local configuration from macros.py (gitignored)
# Run `python setup_macros.py` to generate it from your environment variables
# TODO: remove
# TODO: Hardcode your path to the jepa-wms repo here
jepa_dir = "/home/basileterv/jepa-wms"

sys.path.insert(0, jepa_dir)
from macros import JEPA_WM_HOME, CHECKPOINT_ROOT
local_plan_common_dir = os.path.join(jepa_dir, "app/plan_common/local")
print(f"{local_plan_common_dir=}")

from app.plan_common.plot.logs_plan_joint_unif_utils import (
    collect_task_eval_data,
    plot_task_eval_data,
)
from app.plan_common.plot.aliases import eval_setup_aliases
# Out:
# local_plan_common_dir='/home/basileterv/jepa-wms/app/plan_common/local'
# Bad key keymap.all_axes in file /tmp/par_unpack.bento_cloud.656912.71c720f4ff83643871ec61f3b5be1e2c/bento/server/matplotlibrc-3.1.3, line 76 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.10.8/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %%
base_dir = os.path.join(local_plan_common_dir, 'paper-app')
base_dir = os.path.join(base_dir, 'mw_final_sweep')
os.makedirs(base_dir, exist_ok=True)

model_training_folders = [
      # Central run
    (os.path.join(CHECKPOINT_ROOT, 'mw_final_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_seed1'),
     'WM'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_final_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_repro_1roll_save'),
     'WM-prop'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_final_sweep/mw_4f_fsk5_ask1_r256_dv3vits_vjtranoaug_pred_AdaLN_ftprop_depth6_repro_2roll_save'),
     'Ours'),
]

task_subset = ["mw-reach", "mw-reach-wall"]

task_eval_data = collect_task_eval_data(
  model_training_folders,
  task_subset,
  eval_setup_aliases=eval_setup_aliases,
)

plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  truncate_epoch=50, y_min=0, y_max=90,
  average_seeds=True,
)
# Out:
# ...
# Saved plot to /home/basileterv/jepa-wms/app/plan_common/local/paper-app/mw_final_sweep/mw-reach_GD $L_2$_success rate (%)_evolution.pdf
# Plotting mw-reach/GD $L_2$/Success Rate (%) took 0.76 seconds
# Saved plot to /home/basileterv/jepa-wms/app/plan_common/local/paper-app/mw_final_sweep/mw-reach_CEM $L_2$_success rate (%)_evolution.pdf
# Plotting mw-reach/CEM $L_2$/Success Rate (%) took 0.53 seconds
# Saved plot to /home/basileterv/jepa-wms/app/plan_common/local/paper-app/mw_final_sweep/mw-reach_NG $L_2$_success rate (%)_evolution.pdf
# Plotting mw-reach/NG $L_2$/Success Rate (%) took 0.43 seconds
# Saved plot to /home/basileterv/jepa-wms/app/plan_common/local/paper-app/mw_final_sweep/mw-reach-wall_CEM $L_2$_success rate (%)_evolution.pdf
# Plotting mw-reach-wall/CEM $L_2$/Success Rate (%) took 0.45 seconds
# Saved plot to /home/basileterv/jepa-wms/app/plan_common/local/paper-app/mw_final_sweep/mw-reach_NG $L_1$_success rate (%)_evolution.pdf
# ...

# %%
base_dir = os.path.join(local_plan_common_dir, 'paper-app')
base_dir = os.path.join(base_dir, 'mw_sweep')
os.makedirs(base_dir, exist_ok=True)

model_training_folders = [
      # Central run
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save'),
     'WM'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_hist7'),
      r'$\text{WM}_W$'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_repro_1roll_save'),
     'WM-prop'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_2roll_save'),
     'WM-2-step'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_3roll_save'),
     'WM-3-step'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_6roll_hist7_bs4_save'),
      r'$\text{WM}_W$-6-step'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_dinovitb_depth6_noprop_repro_1roll_save'),
     'WM-B'),
    (os.path.join(CHECKPOINT_ROOT, 'mw_sweep/mw_4f_fsk5_ask1_r224_pred_dino_wm_dinovitl_depth6_noprop_repro_1roll_save'),
     'WM-L'),
]

task_subset = ["mw-reach", "mw-reach-wall"]

task_eval_data = collect_task_eval_data(
  model_training_folders,
  task_subset,
  eval_setup_aliases=eval_setup_aliases,
)

plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  truncate_epoch=50, y_min=0, y_max=90,
  average_seeds=True,
)
# Out:
#   Skipping eval setup L1_noprop_ng_sourcexp_H6_nas3_ctxt2 for task bin-picking as it's not in aliases
#   Skipping eval setup L1_ng_sourcexp_H15_nas15_ctxt2 for task mw-reach as it's not in aliases
#   Skipping eval setup L2_cem_sourcexp_H15_nas15_ctxt2 for task mw-reach-wall as it's not in aliases
#   Skipping eval setup L2_cem_sourcexp_H15_nas15_ctxt2 for task mw-reach as it's not in aliases
#   Skipping eval setup L1_cem_sourcexp_H15_nas15_ctxt2 for task mw-reach as it's not in aliases
#   Skipping eval setup L2_ng_sourcexp_H15_nas15_ctxt2 for task mw-reach-wall as it's not in aliases
#   Skipping eval setup L1_ng_sourcexp_H15_nas15_ctxt2 for task mw-reach-wall as it's not in aliases
#   Skipping eval setup L1_cem_sourcexp_H15_nas15_ctxt2 for task mw-reach-wall as it's not in aliases
#   Skipping eval setup L2_ng_sourcexp_H15_nas15_ctxt2 for task mw-reach as it's not in aliases
#   Skipping eval setup L2_ng_sourcexp_H15_nas15_ctxt2 for task mw-reach-wall as it's not in aliases
# ...

# %%
base_dir = os.path.join(local_plan_common_dir, 'paper-app')
base_dir = os.path.join(base_dir, 'wall_sweep')
os.makedirs(base_dir, exist_ok=True)

model_training_folders = [
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_2n'),
     'WM'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_hist7_2n_lightfreq100'),
      r'$\text{WM}_W$'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_repro_1roll_save_2n'),
     'WM-prop'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_2roll_save_2n'),
     'WM-2-step'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_3roll_save_2n'),
     'WM-3-step'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_6roll_hist7_bs4_save_2n'),
      r'$\text{WM}_W$-6-step'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_dinovitb_depth6_noprop_repro_1roll_save_2n'),
     'WM-B'),
    (os.path.join(CHECKPOINT_ROOT,'wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_dinovitl_depth6_noprop_repro_1roll_save_2n'),
     'WM-L'),
]
hist1_folders = [
        os.path.join(CHECKPOINT_ROOT, "vjepa_wm/wall_sweep/wall_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_hist1_save_2n")
    ]
task_subset = ["wall"]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    hist1_folders=hist1_folders,
)

plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  y_min=0, y_max=90,
  average_seeds=True,
)
# Out:
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L2_noprop_cem_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L1_noprop_cem_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcerandstate_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcerandstate_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L2_ng_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
#   Skipping eval setup L1_ng_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
# No data found in wall_L1_cem_sourcerandstate_H6_nas6_ctxt2_r224_alpha0.0_ep96
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task wall as it's not in aliases
# ...

# %%
base_dir = os.path.join(local_plan_common_dir, 'paper-app')
base_dir = os.path.join(base_dir, 'pt_sweep')
os.makedirs(base_dir, exist_ok=True)

model_training_folders = [
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save'),
     'WM'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_hist7'),
      r'$\text{WM}_W$'),
    (os.path.join(CHECKPOINT_ROOT,'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_repro_1roll_save'),
     'WM-prop'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_2roll_save'),
     'WM-2-step'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_3roll_save'),
     'WM-3-step'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_6roll_hist7_bs4_save'),
      r'$\text{WM}_W$-6-step'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_dinovitb_depth6_noprop_repro_1roll_save'),
     'WM-B'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_dinovitl_depth6_noprop_repro_1roll_save'),
     'WM-L'),
    (os.path.join(CHECKPOINT_ROOT, 'pt_sweep/dino-wm-repro'),
     'DWM-repro'),
    ('/checkpoint/amaia/video/basileterv/dino_wm/experiment/outputs/2025-02-10/15-30-11_pusht_4n',
     'DWM-kathy'),
    ]
task_subset = ["pt"]
hist1_folders = [
    os.path.join(CHECKPOINT_ROOT, "pt_sweep/pt_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_hist1_save"),
]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    hist1_folders=hist1_folders,
)
plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  y_min=0, y_max=90, truncate_epoch=50,
  average_seeds=True,
)
# Out:
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
# No data found in pt_L1_cem_sourcedset_H6_nas6_ctxt2_r224_alpha0.1_ep96
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task pt as it's not in aliases
# ...

# %%
base_dir = os.path.join(local_plan_common_dir, 'paper-app')
base_dir = os.path.join(base_dir, 'mz_sweep')
os.makedirs(base_dir, exist_ok=True)

model_training_folders = [
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_2n'),
     'WM'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_save_hist7_2n_lightfreq100'),
      r'$\text{WM}_W$'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_repro_1roll_save_2n'),
     'WM-prop'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_2roll_save_2n'),
     'WM-2-step'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_3roll_save_2n'),
     'WM-3-step'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_6roll_hist7_bs4_save_2n'),
      r'$\text{WM}_W$-6-step'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_dinovitl_depth6_noprop_repro_1roll_save_2n'),
     'WM-L'),
    (os.path.join(CHECKPOINT_ROOT, 'mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_dinovitb_depth6_noprop_repro_1roll_save_2n'),
     'WM-B'),
    ]
hist1_folders = [
    os.path.join(CHECKPOINT_ROOT, "mz_sweep/mz_4f_fsk5_ask1_r224_pred_dino_wm_depth6_noprop_repro_1roll_hist1_save_2n"),
]
task_subset = ["mz"]
task_eval_data = collect_task_eval_data(
    model_training_folders, task_subset,
    eval_setup_aliases=eval_setup_aliases,
    hist1_folders=hist1_folders,
)
plot_task_eval_data(
  task_eval_data, y_values=['SR'], smooth=True, alpha=0.2,
  show_original=True, base_dir=base_dir, put_title=True, eval_setup_aliases=eval_setup_aliases,
  y_min=0, y_max=100,
  average_seeds=True,
)
# Out:
#   Skipping eval setup L1_noprop_ng_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L1_noprop_cem_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L2_noprop_cem_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcerandstate_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L1_noprop_ng_sourcerandstate_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L2_ng_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L1_ng_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcerandstate_H6_nas6_ctxt2 for task mz as it's not in aliases
#   Skipping eval setup L2_noprop_ng_sourcedset_H6_nas6_ctxt2 for task mz as it's not in aliases
# ...
